# %%
import matplotlib.pylab as plt
import pandas as pd
from pandas.tools.plotting import scatter_matrix

data = pd.read_csv("bank1.csv", sep = ';', decimal = '.', header = 0, names = ['age','job','marital', 'education','default','housing','loan','contact','month','day_of_week','duration','campaign','pdays','previous','poutcome','emp_var_rate','cons_price_idx','cons_conf_idx','euribor3m','nr_employed','y'], na_values = 'NaN')

# %%
data.head()
# Out:
#     age          job  marital          education default  housing     loan  \
# 0  30.0  blue-collar  married           basic.9y      no      yes       no
# 1  39.0     services   single        high.school      no       no       no
# 2  25.0     services  married        high.school      no      yes       no
# 3  38.0     services  married           basic.9y      no  unknown  unknown
# 4  47.0       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri ...       2.0  999.0       0.0  nonexistent
# 1  telephone   may         fri ...       4.0  999.0       0.0  nonexistent
# 2  telephone   jun         wed ...       1.0  999.0       0.0  nonexistent
# 3  telephone   jun         fri ...       3.0  999.0       0.0  nonexistent
# 4   cellular   nov         mon ...       1.0  999.0       0.0  nonexistent
#
# ...

# %%
data.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp_var_rate      float64
# cons_price_idx    float64
# cons_conf_idx     float64
# euribor3m         float64
# nr_employed       float64
# y                  object
# dtype: object

# %%
data['marital'] = data['marital'].astype('category')
data['education'] = data['education'].astype('category')
data['default'] = data['default'].astype('category')
data['housing'] = data['housing'].astype('category')
data['loan'] = data['loan'].astype('category')
data['contact'] = data['contact'].astype('category')
data['month'] = data['month'].astype('category')
data['day_of_week'] = data['day_of_week'].astype('category')
data['poutcome'] = data['poutcome'].astype('category')
data['y'] = data['y'].astype('category')
data['job'] = data['job'].astype('category')

# %%
data.shape
# Out:
# (4103, 21)

# %%
plt.figure(figsize=(10,10))
data['age'].plot(kind = 'hist', bins = 30)
plt.title('Age Distribution', fontsize = 15)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.savefig('age.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['age'].plot(kind = 'hist', bins = 30)
plt.title('Age Distribution', fontsize = 15)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.savefig('frequency.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['job'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Job Distribution', fontsize = 15)
plt.ylabel('Job', fontsize = 15)
plt.savefig('job.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['marital'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Marital Distribution', fontsize = 15)
plt.ylabel('Marital', fontsize = 15)
plt.savefig('marital.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['education'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Education Distribution', fontsize = 15)
plt.ylabel('Education', fontsize = 15)
plt.savefig('education.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['default'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Default in Credit Distribution', fontsize = 15)
plt.ylabel('Default', fontsize = 15)
plt.savefig('default.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['housing'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Housing Distribution', fontsize = 15)
plt.ylabel('Housing', fontsize = 15)
plt.savefig('housing.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['contact'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Contact Distribution', fontsize = 15)
plt.ylabel('Contact', fontsize = 15)
plt.savefig('contact.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['month'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Month of Contact Distribution', fontsize = 15)
plt.ylabel('Month', fontsize = 15)
plt.savefig('month.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['day_of_week'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Last Contact From Week Distribution', fontsize = 15)
plt.ylabel('Weeks', fontsize = 15)
plt.savefig('week.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['duration'].plot(kind = 'hist')
plt.title('Duration of Last Contact Distribution', fontsize = 15)
plt.xlabel('Duration', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.savefig('duration.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['campaign'].plot(kind = 'hist')
plt.title('Number of Contact During Campaign Distribution', fontsize = 15)
plt.xlabel('Duration', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.savefig('campaign.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['pdays'].plot(kind = 'density')
plt.title('Density of Number of Days After Contact', fontsize = 15)
plt.xlabel('Previously Contact of Days', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.savefig('pdays.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['previous'].plot(kind = 'hist', bins = 10)
plt.title('Number of Contacts Before the Campaign', fontsize = 15)
plt.xlabel('Previous Number of Contact', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.savefig('previous.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['poutcome'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Outcome of Previous Marketing Campaign', fontsize = 15)
plt.ylabel('Previous Campaign', fontsize = 15)
plt.savefig('poutcome.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['emp_var_rate'].plot(kind = 'Density')
plt.title('Employment Variation Rate Distribution(Quarterly))', fontsize = 15)
plt.xlabel('Employment Variation Rate', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.savefig('emp_var_rate.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['cons_price_idx'].plot(kind = 'Density')
plt.title('Consumer Price Index Distribution(Monthly))', fontsize = 15)
plt.xlabel('Consumer Price Index', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.savefig('cons_price.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['cons_conf_idx'].plot(kind = 'Density')
plt.title('Consumer Confidence Index Distribution(Monthly))', fontsize = 15)
plt.xlabel('Consumer Confidence Index', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.savefig('cons_conf.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['euribor3m'].plot(kind = 'Density')
plt.title('Euribor 3 Month rate (Daily))', fontsize = 15)
plt.xlabel('Euribor 3 Month Rate', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.savefig('euribor3m.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['nr_employed'].plot(kind = 'Density')
plt.title('Number of Employees (Quarterly))', fontsize = 15)
plt.xlabel('Number of Employees', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
plt.savefig('nr_employed.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
data['y'].value_counts().plot(kind ='pie', autopct = '%.2f')
plt.title('Subscribed Status', fontsize = 15)
plt.ylabel('Subscribed', fontsize = 15)
plt.savefig('y.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,9]
data.plot(kind = 'scatter', x = 'age', y ='cons_conf_idx')
plt.title('Relationship between Age and Consumer Confidence Index', fontsize = 15)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Consumer Confidence Index', fontsize = 15)
plt.savefig('age_cons.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,9]
data.boxplot(column = 'emp_var_rate', by = 'marital')
plt.title('Boxplot of Marital by Employment Variation Rate', fontsize = 15)
plt.xlabel('Marital', fontsize = 15)
plt.savefig('boxplot1.png')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [16,9]
data.boxplot(column = 'cons_conf_idx', by ='education')
plt.title('Relationship between Education and Consumer Confidence Index', fontsize = 15)
plt.xlabel('Education', fontsize = 15)
plt.ylabel('Consumer Confidence Index', fontsize = 15)
plt.savefig('boxplot2.png')
plt.show()

# %%
data_num = data[['age','duration','campaign', 'pdays','previous','emp_var_rate','cons_price_idx','cons_conf_idx','euribor3m','nr_employed']]

# %%
scatter_matrix(data_num, alpha = 0.2, figsize=(16,16), diagonal = 'hist')
plt.savefig('scatter.png')
plt.show()
# Out:
# /anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
